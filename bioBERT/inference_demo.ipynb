# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline


def run_ner_demo(model_name: str, texts: list, description: str = ""):
    """주어진 모델로 NER pipeline을 실행하고 결과를 보기 좋게 출력"""
    print(f"\n{'=' * 78}")
    print(f"Model: {model_name}")
    if description:
        print(f"Desc : {description}")
    print(f"{'=' * 78}")

    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForTokenClassification.from_pretrained(model_name)
    ner = pipeline(
        "ner",
        model=model,
        tokenizer=tokenizer,
        aggregation_strategy="simple",  # subword들을 word 단위로 묶어줌
    )

    for text in texts:
        print(f"\n[INPUT] {text}")
        entities = ner(text)
        if not entities:
            print("   (no entities detected)")
            continue
        for ent in entities:
            print(
                f"   - {ent['word']:30s} | "
                f"{ent['entity_group']:15s} | "
                f"score={ent['score']:.3f}"
            )


if __name__ == "__main__":
    biomedical_texts = [
        "BRCA1 mutations significantly increase the risk of breast cancer and ovarian cancer.",
        "The patient was diagnosed with type 2 diabetes mellitus and prescribed metformin 500mg.",
        "Aspirin reduces inflammation and is used for acute myocardial infarction.",
        "TP53 is a tumor suppressor gene mutated in many cancers including lung adenocarcinoma.",
        "COVID-19, caused by SARS-CoV-2, has been treated with remdesivir and dexamethasone.",
    ]

    # 1) BioBERT - Disease NER (NCBI Disease로 fine-tuning)
    run_ner_demo(
        "alvaroalon2/biobert_diseases_ner",
        biomedical_texts,
        description="BioBERT fine-tuned for Disease NER (NCBI Disease)",
    )

    # 2) BioBERT - Chemical/Drug NER
    run_ner_demo(
        "alvaroalon2/biobert_chemical_ner",
        biomedical_texts,
        description="BioBERT fine-tuned for Chemical NER (BC5CDR-Chem)",
    )

    # 3) BioBERT - Gene/Protein NER
    run_ner_demo(
        "alvaroalon2/biobert_genetic_ner",
        biomedical_texts,
        description="BioBERT fine-tuned for Genetic/Protein NER (BC2GM)",
    )

    # 4) (참고) BioBERT는 아니지만 multi-type 비교용 - 84개 entity type
    run_ner_demo(
        "d4data/biomedical-ner-all",
        biomedical_texts,
        description="[참고] BERT-based biomedical NER, 84 entity types",
    )
# Out:
# ==============================================================================
# Model: alvaroalon2/biobert_diseases_ner
# Desc : BioBERT fine-tuned for Disease NER (NCBI Disease)
# ==============================================================================
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/431M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/431M [00:00<?, ?B/s]
# BertForTokenClassification LOAD REPORT from: alvaroalon2/biobert_diseases_ner
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INPUT] BRCA1 mutations significantly increase the risk of breast cancer and ovarian cancer.
#    - BRCA1 mutations significantly increase the risk of | 0               | score=1.000
#    - breast cancer                  | DISEASE         | score=1.000
#    - and                            | 0               | score=1.000
#    - ovarian cancer                 | DISEASE         | score=0.996
#    - .                              | 0               | score=1.000
#
# [INPUT] The patient was diagnosed with type 2 diabetes mellitus and prescribed metformin 500mg.
#    - The patient was diagnosed with | 0               | score=1.000
#    - type 2 diabetes mellitus       | DISEASE         | score=1.000
#    - and prescribed metformin 500mg. | 0               | score=1.000
#
# [INPUT] Aspirin reduces inflammation and is used for acute myocardial infarction.
#    - Aspirin reduces                | 0               | score=1.000
#    - inflammation                   | DISEASE         | score=1.000
#    - and is used for                | 0               | score=1.000
#    - acute myocardial infarction    | DISEASE         | score=0.999
#    - .                              | 0               | score=1.000
#
# [INPUT] TP53 is a tumor suppressor gene mutated in many cancers including lung adenocarcinoma.
#    - TP53 is a                      | 0               | score=1.000
#    - tumor                          | DISEASE         | score=1.000
#    - suppressor gene mutated in many | 0               | score=1.000
#    - cancer                         | DISEASE         | score=1.000
#    - ##s including                  | 0               | score=1.000
#    - lung adenocarcinoma            | DISEASE         | score=1.000
#    - .                              | 0               | score=1.000
#
# [INPUT] COVID-19, caused by SARS-CoV-2, has been treated with remdesivir and dexamethasone.
#    - COVID - 19                     | DISEASE         | score=0.979
#    - , caused by                    | 0               | score=1.000
#    - SARS - CoV - 2                 | DISEASE         | score=0.948
#    - , has been treated with remdesivir and dexamethasone. | 0               | score=1.000
#
# ==============================================================================
# Model: alvaroalon2/biobert_chemical_ner
# Desc : BioBERT fine-tuned for Chemical NER (BC5CDR-Chem)
# ==============================================================================
# config.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/alvaroalon2/biobert_chemical_ner/resolve/main/chat_template.jinja
# WARNING:huggingface_hub.utils._http:HTTP Error 429 thrown while requesting HEAD https://huggingface.co/alvaroalon2/biobert_chemical_ner/resolve/main/chat_template.jinja
# Rate limited. Waiting 229.0s before retry [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Rate limited. Waiting 229.0s before retry [Retry 1/5].
# pytorch_model.bin:   0%|          | 0.00/431M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/431M [00:00<?, ?B/s]
# BertForTokenClassification LOAD REPORT from: alvaroalon2/biobert_chemical_ner
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INPUT] BRCA1 mutations significantly increase the risk of breast cancer and ovarian cancer.
#    (no entities detected)
#
# [INPUT] The patient was diagnosed with type 2 diabetes mellitus and prescribed metformin 500mg.
#    - metformin                      | CHEMICAL        | score=0.985
#
# [INPUT] Aspirin reduces inflammation and is used for acute myocardial infarction.
#    - Aspirin                        | CHEMICAL        | score=0.993
#
# [INPUT] TP53 is a tumor suppressor gene mutated in many cancers including lung adenocarcinoma.
#    (no entities detected)
#
# [INPUT] COVID-19, caused by SARS-CoV-2, has been treated with remdesivir and dexamethasone.
#    - re                             | CHEMICAL        | score=1.000
#    - ##mdes                         | CHEMICAL        | score=0.892
#    - ##ir                           | CHEMICAL        | score=0.584
#    - dexamethasone                  | CHEMICAL        | score=0.987
#
# ==============================================================================
# Model: alvaroalon2/biobert_genetic_ner
# Desc : BioBERT fine-tuned for Genetic/Protein NER (BC2GM)
# ==============================================================================
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/431M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/431M [00:00<?, ?B/s]
# BertForTokenClassification LOAD REPORT from: alvaroalon2/biobert_genetic_ner
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [INPUT] BRCA1 mutations significantly increase the risk of breast cancer and ovarian cancer.
#    - BRCA1                          | GENETIC         | score=1.000
#
# [INPUT] The patient was diagnosed with type 2 diabetes mellitus and prescribed metformin 500mg.
#    (no entities detected)
#
# [INPUT] Aspirin reduces inflammation and is used for acute myocardial infarction.
#    (no entities detected)
#
# [INPUT] TP53 is a tumor suppressor gene mutated in many cancers including lung adenocarcinoma.
#    - TP53                           | GENETIC         | score=1.000
#
# [INPUT] COVID-19, caused by SARS-CoV-2, has been treated with remdesivir and dexamethasone.
#    (no entities detected)
#
# ==============================================================================
# Model: d4data/biomedical-ner-all
# Desc : [참고] BERT-based biomedical NER, 84 entity types
# ==============================================================================
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/266M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# [INPUT] BRCA1 mutations significantly increase the risk of breast cancer and ovarian cancer.
#    - br                             | Diagnostic_procedure | score=0.995
#    - ##ca1 mutations                | Coreference     | score=0.802
#    - breast                         | Biological_structure | score=0.655
#
# [INPUT] The patient was diagnosed with type 2 diabetes mellitus and prescribed metformin 500mg.
#    - type 2 diabetes mellitus       | Disease_disorder | score=0.934
#    - metformin                      | Medication      | score=0.999
#    - 500                            | Dosage          | score=0.600
#
# [INPUT] Aspirin reduces inflammation and is used for acute myocardial infarction.
#    - as                             | Medication      | score=1.000
#    - ##pi                           | Medication      | score=0.984
#    - ##rin                          | Medication      | score=0.649
#    - inflammation                   | Disease_disorder | score=0.540
#    - acute                          | Detailed_description | score=0.990
#
# [INPUT] TP53 is a tumor suppressor gene mutated in many cancers including lung adenocarcinoma.
#    - tp53                           | Diagnostic_procedure | score=0.977
#    - lung                           | Biological_structure | score=0.999
#
# [INPUT] COVID-19, caused by SARS-CoV-2, has been treated with remdesivir and dexamethasone.
#    - co                             | Diagnostic_procedure | score=0.999
#    - ##vid - 19                     | Diagnostic_procedure | score=0.858
#    - sar                            | Diagnostic_procedure | score=0.936
#    - re                             | Medication      | score=1.000
#    - ##md                           | Medication      | score=1.000
#    - ##es                           | Medication      | score=0.999
#    - ##ivir                         | Medication      | score=0.913
#    - dex                            | Medication      | score=0.999
#    - ##ame                          | Medication      | score=0.637
#    - ##thason                       | Medication      | score=0.930
